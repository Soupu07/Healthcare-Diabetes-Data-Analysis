# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('health care diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.shape
# Out:
# (768, 9)

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
plt.hist(data['Glucose'])
plt.xlabel('Glucose Class')
plt.plot()
# Out:
# []

# %%
# !pip install DataScienceHelper
import DataScienceHelper as dsh

# %%
plt.figure(figsize = (20,20))
sns.set_style(style='darkgrid')

plt.subplot(4,2,1)
plt.hist(data['Glucose'], bins = 15)
plt.title('A Histogram of Glucose')

plt.subplot(4,2,2)
plt.hist(data['Pregnancies'], bins = 15)
plt.title('A Histogram of Pregnancies')

plt.subplot(4,2,3)
plt.hist(data['BloodPressure'], bins = 15)
plt.title('A Histogram of BloodPressure')

plt.subplot(4,2,4)
plt.hist(data['SkinThickness'], bins = 15)
plt.title('A Histogram of SkinThickness')

plt.subplot(4,2,5)
plt.hist(data['Insulin'], bins = 15)
plt.title('A Histogram of Insulin')

plt.subplot(4,2,6)
plt.hist(data['BMI'], bins = 15)
plt.title('A Histogram of BMI')

plt.subplot(4,2,7)
plt.hist(data['DiabetesPedigreeFunction'], bins = 15)
plt.title('A Histogram of DiabetesPedigreeFunction')

plt.subplot(4,2,8)
plt.hist(data['Age'], bins = 15)
plt.title('A Histogram of Age')
# Out:
# Text(0.5, 1.0, 'A Histogram of Age')

# %%
Positive = data[data['Outcome']==1]
Positive.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 6            3       78             50             32       88  31.0
# 8            2      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 2                     0.672   32        1
# 4                     2.288   33        1
# 6                     0.248   26        1
# 8                     0.158   53        1

# %%
plt.figure(figsize = (20,20))
sns.set_style(style='darkgrid')

plt.subplot(4,2,1)
plt.hist(Positive['Glucose'], bins = 30)
plt.title('A Histogram of Glucose')

plt.subplot(4,2,2)
plt.hist(Positive['Pregnancies'], bins = 30)
plt.title('A Histogram of Pregnancies')

plt.subplot(4,2,3)
plt.hist(Positive['BloodPressure'], bins = 30)
plt.title('A Histogram of BloodPressure')

plt.subplot(4,2,4)
plt.hist(Positive['SkinThickness'], bins = 30)
plt.title('A Histogram of SkinThickness')

plt.subplot(4,2,5)
plt.hist(Positive['Insulin'], bins = 30)
plt.title('A Histogram of Insulin')

plt.subplot(4,2,6)
plt.hist(Positive['BMI'], bins = 30)
plt.title('A Histogram of BMI')

plt.subplot(4,2,7)
plt.hist(Positive['DiabetesPedigreeFunction'], bins = 30)
plt.title('A Histogram of DiabetesPedigreeFUnction')

plt.subplot(4,2,8)
plt.hist(Positive['Age'], bins = 30)
plt.title('A Histogram of Age')
# Out:
# Text(0.5, 1.0, 'A Histogram of Age')

# %%
plt.figure(figsize = (15,10))

plt.subplot(2,2,1)
sns.scatterplot( x = 'Glucose',y = 'BloodPressure' ,hue="Outcome",data=data)

plt.subplot(2,2,2)
sns.scatterplot( x = 'BMI',y = 'Insulin' ,hue="Outcome",data=data)

plt.subplot(2,2,3)
sns.scatterplot( x = 'SkinThickness',y = 'Insulin' ,hue="Outcome",data=data)

plt.subplot(2,2,4)
sns.scatterplot( x = 'DiabetesPedigreeFunction',y = 'Insulin' ,hue="Outcome",data=data)
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Insulin'>

# %%
sns.countplot(data['Outcome'])
plt.title("Countplot of Outcome")
plt.xlabel('Outcome')
plt.ylabel("Count")
print("Count of class is:\n",data['Outcome'].value_counts())
# Out:
# Count of class is:
#  Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,10))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y ,test_size=0.2, random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.7833876221498371
# 0.7792207792207793

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y,model.predict(x))
cm
# Out:
# array([[447,  53],
#        [114, 154]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y,model.predict(x)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       500
#            1       0.74      0.57      0.65       268
#
#     accuracy                           0.78       768
#    macro avg       0.77      0.73      0.75       768
# weighted avg       0.78      0.78      0.77       768

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
probs = model.predict_proba(x)
probs = probs[:, 1]
auc = roc_auc_score(y, probs)
print('AUC: %.3f' % auc)
fpr, tpr, thresholds = roc_curve(y, probs)
plt.plot([0, 1], [0, 1],color = 'green' ,linestyle='--')
plt.plot(fpr, tpr,'r', marker='.')
plt.show()
# Out:
# AUC: 0.840

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
knn_model = KNeighborsClassifier(n_neighbors=6)
knn_model.fit(x_train,y_train)
knn_pred=knn_model.predict(x_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of KNN Model::")
print(metrics.accuracy_score(y_test,knn_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,knn_pred),'\n')
print("\n","ROC Curve")
knn_prob=knn_model.predict_proba(x_test)
knn_prob1=knn_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,knn_prob1)
roc_auc_knn=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'r',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='green')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of KNN Model::
# 0.7727272727272727
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        99
#            1       0.78      0.51      0.62        55
#
#     accuracy                           0.77       154
#    macro avg       0.77      0.71      0.73       154
# weighted avg       0.77      0.77      0.76       154
#
#
#
#  ROC Curve

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
svc_model_linear = SVC(kernel='linear',random_state=0,probability=True,C=0.01)
svc_model_linear.fit(x_train,y_train)
svc_pred=svc_model_linear.predict(x_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of SVC Model with Linear Kernel::")
print(metrics.accuracy_score(y_test,svc_pred))
print("\n", "Classification Report::")
print(metrics.classification_report(y_test,svc_pred),'\n')
print("\n","ROC Curve")
svc_prob_linear=svc_model_linear.predict_proba(x_test)
svc_prob_linear1=svc_prob_linear[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,svc_prob_linear1)
roc_auc_svc=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'r',label='AUC Score = %0.2f'%roc_auc_svc)
plt.plot(fpr,fpr,'r--',color='green')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of SVC Model with Linear Kernel::
# 0.7662337662337663
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83        99
#            1       0.73      0.55      0.62        55
#
#     accuracy                           0.77       154
#    macro avg       0.76      0.72      0.73       154
# weighted avg       0.76      0.77      0.76       154
#
#
#
#  ROC Curve

# %% [markdown]
# # Ensemble Learning

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=1000,random_state=0)
rf_model.fit(x_train,y_train)
rf_pred = rf_model.predict(x_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of Logistic Regression Model::")
print(metrics.accuracy_score(y_test,rf_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,rf_pred),'\n')
print("\n","ROC Curve")
rf_prob=rf_model.predict_proba(x_test)
rf_prob1=rf_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,rf_prob1)
roc_auc_rf=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.plot(fpr,tpr,'r',label='AUC Score = %0.2f'%roc_auc_rf)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,fpr,'r--',color='green')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.8116883116883117
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        99
#            1       0.77      0.67      0.72        55
#
#     accuracy                           0.81       154
#    macro avg       0.80      0.78      0.79       154
# weighted avg       0.81      0.81      0.81       154
#
#
#
#  ROC Curve

# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)
print(models)
# Out:
#  97%|█████████▋| 28/29 [00:04<00:00,  5.61it/s]
# [LightGBM] [Info] Number of positive: 213, number of negative: 401
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006619 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 668
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.346906 -> initscore=-0.632669
# [LightGBM] [Info] Start training from score -0.632669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.preprocessing import StandardScaler
Scale=StandardScaler()

# %%
x_train_std=Scale.fit_transform(x_train)
x_test_std=Scale.fit_transform(x_test)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True,custom_metric=None)
models,predictions = clf.fit(x_train_std, x_test_std, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:03<00:00,  9.35it/s]
# [LightGBM] [Info] Number of positive: 213, number of negative: 401
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 668
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.346906 -> initscore=-0.632669
# [LightGBM] [Info] Start training from score -0.632669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Here After Standardization the accuracy of some models are increased

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
knn_model = KNeighborsClassifier(n_neighbors=25)
knn_model.fit(x_train_std,y_train)
knn_pred=knn_model.predict(x_test_std)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of KNN Model::")
print(metrics.accuracy_score(y_test,knn_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,knn_pred),'\n')
print("\n","ROC Curve")
knn_prob=knn_model.predict_proba(x_test_std)
knn_prob1=knn_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,knn_prob1)
roc_auc_knn=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'m',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='cyan')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of KNN Model::
# 0.7922077922077922
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85        99
#            1       0.79      0.56      0.66        55
#
#     accuracy                           0.79       154
#    macro avg       0.79      0.74      0.76       154
# weighted avg       0.79      0.79      0.78       154
#
#
#
#  ROC Curve
